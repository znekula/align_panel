# %%
import panel as pn
pn.extension()
import aperture as ap
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
fig = ap.figure()
fig.add_image(height=400, width=600)
poly = fig.add_polygons(allow_edit=True)
fig
# Out:
# BokehFigure(Figure)

# %%
poly.export_data()
# Out:
#                                                   xs  \
# 0            [199.29165649414062, 360.2916564941406]
# 1  [221.29165649414062, 287.2916564941406, 476.29...
#
#                                                   ys _an_type
# 0           [127.88541412353516, 116.88541412353516]  polygon
# 1  [251.88541412353516, 305.88541412353516, 260.8...  polygon

# %%
import yaml

from bokeh.layouts import column
from bokeh.models import ColumnDataSource, Slider, TableColumn, PointDrawTool, DataTable
from bokeh.plotting import figure
from bokeh.themes import Theme
from bokeh.io import show, output_notebook

from bokeh.sampledata.sea_surface_temperature import sea_surface_temperature

output_notebook()

def modify_doc(doc):
    p = figure(title = 'scope')
    source = ColumnDataSource({'x':[1,5,9], 'y':[1,5,9], 'color':['red','red','red'] })
    renderer = p.scatter(x='x', y='y',source=source, color = 'color', size= 10)
    columns = [
        TableColumn(field="x", title = "x"),
        TableColumn(field="x", title = "x"),
        TableColumn(field="color", title = "color")
        ]
    table = DataTable(source=source, columns = columns, editable = True, height = 200)
    draw_tool = PointDrawTool(renderers=[renderer], empty_value = 'black')
    p.add_tools(draw_tool)
    p.toolbar.active_tap = draw_tool
    doc.add_root(column(p, table))
    

show(modify_doc, notebook_url = "localhost:8888")
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4011">Loading BokehJS ...</span>
#     </div>
# <script id="4012">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:61037/autoload.js?bokeh-autoload-element=4012&bokeh-absolute-url=http://localhost:61037&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
